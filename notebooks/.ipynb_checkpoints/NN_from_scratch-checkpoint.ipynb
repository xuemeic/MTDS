# %% [markdown]
# # Build a Simple Neural Network

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error

# %% [markdown]
# ## Define some functions

# %%
def relu(x):
    # relu function
    return np.maximum(x, 0)

# %%
# test relu
relu(np.array([[-2, 3],
              [5, -3]]))
# Out:
# array([[0, 3],
#        [5, 0]])

# %%
def cost_J(u, y):
    # MSE cost function: 1 / 2 * ||u-y||^2
    return 0.5*(np.sum((u - y)**2))

# %%
# test cost
cost_J(np.array([1,2]), np.array([2,3]))
# Out:
# np.float64(1.0)

# %% [markdown]
# ## train the weights
# The XOR (Exclusive OR) function is a logical operation that returns TRUE if exactly one of the inputs is true, but FALSE if both are true or both are false

# %%
# XOR function
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([0, 1, 1, 0]).reshape([-1, 1])
# "-1" above means automatically compute the other dimension
print(X)
print(y)
# Out:
# [[0 0]
#  [0 1]
#  [1 0]
#  [1 1]]
# [[0]
#  [1]
#  [1]
#  [0]]

# %%
n, p = X.shape

# size (number of nodes) of hidden layer
p1 = 5
lr = 1e-1
max_iter = 30

# initialization
np.random.seed(2)
W1 = np.random.randn(p, p1) # shape is p by p1
W2 = np.random.randn(p1, 1)

for i in range(max_iter):
    # forward propargation (usually should be a for loop, iterate over how many hidden layers there are)
    u1 = X@W1
    h = relu(u1)
    u2 = h@W2

    # compute cost
    J = cost_J(u2, y)
    #print(J)

    # backward propagation for computing gradient (usually a for loop iterate over # of hidden layers)
    du2 = u2 - y
    dW2 = (h.T)@du2
    dh = du2@W2.T
    # du1 = dh*r'(u1): if u1(i,j) > 0, then du1(i,j)=dh(i,j); if u1(i,j) <= 0, then du1(i,j)=0
    du1 = dh*relu(np.sign(u1))
    dW1 = X.T@du1
    
    # gradient descent
    W1 = W1 - lr * dW1
    W2 = W2 - lr * dW2
print(u2)
# Out:
# [[0.        ]
#  [0.99999995]
#  [0.96052743]
#  [0.07128983]]

# %% [markdown]
# ## Try train this with linear regression: fail

# %%
lm = LinearRegression().fit(X,y)
print(lm.predict(X))
print(y)
# Out:
# [[0.5]
#  [0.5]
#  [0.5]
#  [0.5]]
# [[0]
#  [1]
#  [1]
#  [0]]

# %% [markdown]
# ## Let's try to use our NN to do housing prediction

# %%
# data prep
ames = pd.read_csv("../data/ames.csv")
ames_num = ames.select_dtypes(exclude=['object'])
yh = ames['Sale_Price']
Xh = ames_num.iloc[:,:-3] # selecting all but the last 3 columns
X_train, X_test, y_train, y_test = train_test_split(Xh, yh, test_size = 0.25, random_state = 46)

# %% [markdown]
# ## write a function to do simple NN

# %%
def simple_NN(X, y, seed = 2, lr = 1e-1, hidden_size = 5, max_iter = 30):
    n, p = X.shape
    y = y.reshape([-1, 1])

    # size (number of nodes) of hidden layer
    p1 = hidden_size
    
    # initialization
    np.random.seed(seed)
    W1 = np.random.randn(p, p1) # shape is p by p1
    W2 = np.random.randn(p1, 1)
    
    for i in range(max_iter):
        # forward propargation (usually should be a for loop, iterate over how many hidden layers there are)
        u1 = X@W1
        h = relu(u1)
        u2 = h@W2
    
        # compute cost
        J = cost_J(u2, y)
        #print(J)
    
        # backward propagation for computing gradient (usually a for loop iterate over # of hidden layers)
        du2 = u2 - y
        dW2 = (h.T)@du2
        dh = du2@W2.T
        # du1 = dh*r'(u1): if u1(i,j) > 0, then du1(i,j)=dh(i,j); if u1(i,j) <= 0, then du1(i,j)=0
        du1 = dh*relu(np.sign(u1))
        dW1 = X.T@du1
        
        # gradient descent
        W1 = W1 - lr * dW1
        W2 = W2 - lr * dW2
    return W1, W2, J, u2

# %%
# works on XOR
simple_NN(X,y)
# Out:
# (array([[-0.41675785, -0.43816504, -2.1361961 ,  1.24168812, -1.79343559],
#         [-0.84174737,  0.43270045, -1.24528809, -1.15730864, -0.90900761]]),
#  array([[0.55145404],
#         [2.31106759],
#         [0.04153939],
#         [0.77629113],
#         [0.53905832]]),
#  np.float64(0.003320162025686291),
#  array([[0.        ],
#         [0.99999995],
#         [0.96052743],
#         [0.07128983]]))

# %%
W1, W2, J, u2 = simple_NN(X_train.to_numpy(), y_train.to_numpy(), lr = 1e-9, max_iter = 40)
root_mean_squared_error(u2, y_train.to_numpy())
# Out:
# 199624.30994534056

# %%
u2
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]], shape=(2197, 1))
