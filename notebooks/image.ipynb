# %% [markdown]
# # Convolution

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1D convolution
# `sp.signal.convolve(x, h, mode = )`

# %% [markdown]
# ## 2D convolution

# %% [markdown]
# ## Effects on images

# %%
img = plt.imread("../data/hen.jpeg")
img.shape
# Out:
# (3024, 4032, 3)
